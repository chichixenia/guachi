# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#利用今日(2020/3/3)之3月月選擇權買權價格與履約價,無風險利率以0.5%代入,透過選擇權評價軟體求得各履約價之隱含波動度
strike_price = [10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800]
implied_volatility = [0.2683, 0.2762, 0.2524, 0.2377, 0.2261, 0.2163, 0.2049, 0.192, 0.1815, 0.1709]

# %%
#利用圖形驗證笑狀波幅存在(橫軸為履約價,縱軸為隱含波動度)
plt.title("2020/3/3 TXO-March Implied Volatility Curve of Call")
plt.plot(strike_price, implied_volatility, "c-", linewidth = 3)
plt.xkcd()
